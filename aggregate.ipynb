# %% [markdown]
# <a href="https://colab.research.google.com/github/muneeswarikagitala-web/datascience-and-ml/blob/main/aggregate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/drive/MyDrive/datsetsfordatasciencebytexl/student_dataset_20rows.xlsx")

# %%
df.head()
# Out:
#    Student_ID   Name  Age        Course  Marks        City
# 0         101    Ram   25        Pandas     90  Vijayawada
# 1         102   Ravi   23         NumPy     81   Hyderabad
# 2         103   Sita   21        Python     80     Chennai
# 3         104  Kiran   21  Data Science     98   Bangalore
# 4         105    Anu   20        Pandas     70      Mumbai

# %%
print(df["Marks"].sum())
# Out:
# 1656

# %%
print(df["Marks"].mean())
# Out:
# 82.8

# %%
print(df["Marks"].median())
# Out:
# 81.0

# %%
print(df["Marks"].max())
# Out:
# 99

# %%
print(df["Marks"].min())
# Out:
# 70

# %%
print(df["Marks"].std())
# Out:
# 10.076549116898263

# %%
print(df["Marks"].var())
# Out:
# 101.53684210526318

# %%
print(df["Marks"].count ())
# Out:
# 20

# %%
print(df["Marks"].describe())

# %%
print(df["Marks"].agg(["sum","mean"]))
# Out:
# sum     1656.0
# mean      82.8
# Name: Marks, dtype: float64
